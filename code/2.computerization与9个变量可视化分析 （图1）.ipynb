# %% [markdown]
# ### 2.computerization与9个变量可视化分析（图1）

# %%
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import LeaveOneOut
# scores = cross_val_score(m, X, Y, cv=LeaveOneOut())
# scores.mean()

# %%
df_s=df_s[['O*NET-SOC Code','Element Name','Data Value']]
df_a=df_a[['O*NET-SOC Code','Element Name','Data Value']]
df_k=df_k[['O*NET-SOC Code','Element Name','Data Value']]
df_w=df_w[['O*NET-SOC Code','Element Name','Data Value']]
df_c=df_c[['O*NET-SOC Code','Element Name','Data Value']]
df_zong= pd.concat( [df_s, df_a,df_k,df_w,df_c], axis=0 )
df_zong=df_zong.sort_values(by=['O*NET-SOC Code','Element Name'])
#

# %%
df_zong.to_csv('967个职业各自的九个变量.csv')
# df_zong=pd.read_csv(r'C:\Users\Asus\Desktop\文件夹\项目\人工智能时代媒体就业\17\967个职业各自的九个变量.csv',engine='python')

# %%
# 全部职业(967)的计算机化率

# %%
data_zong=list(df_zong['Data Value'])
X_zong=[]
for i in range(0,8703,9):
    list_zong=data_zong[i:i+9]
    X_zong.append(list_zong)
X_zong=np.array(X_zong)
len(X_zong)
# Out:
# 967

# %%
y_zong_model = m.predict(X_zong)[0]
# y_zong_model
# max(y_zong_model)
# min(y_zong_model)

# %%
fenmu=max(y_zong_model)-min(y_zong_model)

# %%
import math
com_list=[]
for i in y_zong_model:
    com=(i-min(y_zong_model))/fenmu
    com_list.append(com)
# max(com_list)
# com_list
# com_list.tolist()

# %%
com_list=np.array(com_list)

# %%
df_1=df_zong.drop_duplicates(subset='O*NET-SOC Code', keep='first', inplace=False)
df_1['Probability ']=com_list
df_1=df_1.drop(['Element Name',"Data Value"],axis=1)
df_1.index = range(len(df_1))
# Out:
#  C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# df_2_1=df_2.drop(columns=['2018 SOC Code','2018 SOC Title'])
# df_1.merge(df_2_1,on='O*NET-SOC Code',how='left')
# df_1.to_csv('967职业计算机化率.csv')#--每一个职业对应的计算机化水平

# %%
# df_1=pd.read_csv(r'C:\Users\Asus\Desktop\文件夹\项目\人工智能时代媒体就业\17\967职业计算机化率.csv',engine='python')

# %%
pro1= np.array(df_1['Probability '])#np.ndarray()
# pro1_list=pro1.tolist()
c=np.repeat(pro1, 9, axis=None)
# pro1_list.repeats(9)
c
# Out:
# array([0.09925372, 0.09925372, 0.09925372, ..., 0.58255968, 0.58255968,
#        0.58255968])

# %%
# import math
# com_list=[]
# for i in y_zong_model:
#     com=1/(1+math.exp(-i))
#     com=com/0.3
#     com_list.append(com)
# max(com_list)
# # min(com_list)

# %%
df_zong['pro']=c
df_zong
# Out:
#        O*NET-SOC Code                           Element Name  Data Value  \
# 56         11-1011.00        Assisting and Caring for Others        2.18
# 150        11-1011.00  Cramped Work Space, Awkward Positions        1.45
# 51         11-1011.00                              Fine Arts        0.87
# 47         11-1011.00                       Finger Dexterity        2.00
# 45         11-1011.00                       Manual Dexterity        0.00
# 27         11-1011.00                            Negotiation        4.62
# 11         11-1011.00                            Originality        4.25
# 25         11-1011.00                             Persuasion        5.00
# 21         11-1011.00                  Social Perceptiveness        4.25
# 138        11-1011.03        Assisting and Caring for Others        2.23
# 488        11-1011.03  Cramped Work Space, Awkward Positions        1.38
# 117        11-1011.03                              Fine Arts        0.96
# ...

# %%
df_zong=pd.read_csv(r'C:\Users\Asus\Desktop\文件夹\项目\人工智能时代媒体就业\17\df_zong.csv',engine='python')

# %%
df_m17=pd.read_excel(r'C:\Users\Asus\Desktop\文件夹\项目\人工智能时代媒体就业\17/媒体行业17种全数据.xlsx')

df_m_1 = df_m17[df_m17['Element Name'] == 'Assisting and Caring for Others']
df_m_2 = df_m17[df_m17['Element Name'] == 'Persuasion']
df_m_3 = df_m17[df_m17['Element Name'] == 'Negotiation']
df_m_4 = df_m17[df_m17['Element Name'] == 'Social Perceptiveness']
df_m_5 = df_m17[df_m17['Element Name'] == 'Fine Arts']
df_m_6 = df_m17[df_m17['Element Name'] == 'Originality']
df_m_7 = df_m17[df_m17['Element Name'] == 'Manual Dexterity']
df_m_8= df_m17[df_m17['Element Name'] == 'Finger Dexterity']
df_m_9 = df_m17[df_m17['Element Name'] == 'Cramped Work Space, Awkward Positions']

# %%
import pylab as plt
import matplotlib.gridspec as gridspec

df1 = df_zong[df_zong['Element Name'] == 'Assisting and Caring for Others']
df2 = df_zong[df_zong['Element Name'] == 'Persuasion']
df3 = df_zong[df_zong['Element Name'] == 'Negotiation']
df4 = df_zong[df_zong['Element Name'] == 'Social Perceptiveness']
df5 = df_zong[df_zong['Element Name'] == 'Fine Arts']
df6 = df_zong[df_zong['Element Name'] == 'Originality']
df7 = df_zong[df_zong['Element Name'] == 'Manual Dexterity']
df8= df_zong[df_zong['Element Name'] == 'Finger Dexterity']
df9 = df_zong[df_zong['Element Name'] == 'Cramped Work Space, Awkward Positions']


plt.subplots(3, 3, sharex=False, sharey=True)
# plt.title('九个变量与计算机化水平的关系 ',fontsize=15)
fig,subplot_arr=plt.subplots(3,3,figsize=(30,30),dpi=200)
subplot_arr[0, 0].scatter(df1['Data Value'], df1['pro'],c='#696969',s=100.,alpha = .3)
subplot_arr[0, 0].scatter(df_m_1['Data Value'], df_m_1['pro'],c='b',marker = "^",s=250.,alpha = .6)
subplot_arr[0, 0].scatter(df_m1['Data Value'], df_m1['pro'],c='r',marker = "*",s=400.,alpha = .6)
subplot_arr[0, 0].set_ylabel('社交智能类任务计算机化水平',fontsize = 35)
subplot_arr[0, 0].set_xlabel('帮助和关爱他人',fontsize = 35)
subplot_arr[0, 0].tick_params(labelsize=20)

subplot_arr[0, 1].scatter(df2['Data Value'], df2['pro'],c='#696969',s=100.,alpha = .3)
# subplot_arr[0, 1].set_ylabel('计算机化水平',fontsize = 20)
subplot_arr[0, 1].scatter(df_m_2['Data Value'], df_m_2['pro'],c='b',marker = "^",s=250.,alpha = .6)
subplot_arr[0, 1].scatter(df_m2['Data Value'], df_m2['pro'],c='r',marker = "*",s=400.,alpha = .6)
subplot_arr[0, 1].set_xlabel('说服',fontsize = 35)
subplot_arr[0, 1].tick_params(labelsize=20)

subplot_arr[0, 2].scatter(df3['Data Value'], df3['pro'],c='#696969',s=100.,alpha = .3)
# subplot_arr[0, 2].set_ylabel('Computerisation',fontsize = 30)
subplot_arr[0, 2].scatter(df_m_3['Data Value'], df_m_3['pro'],c='b',marker = "^",s=250.,alpha = .6)
subplot_arr[0, 2].scatter(df_m3['Data Value'], df_m3['pro'],c='r',marker = "*",s=400.,alpha = .6)
subplot_arr[0, 2].set_xlabel('谈判',fontsize = 35)
subplot_arr[0, 2].tick_params(labelsize=20)

subplot_arr[1, 0].scatter(df4['Data Value'], df4['pro'],c='#696969',s=100.,alpha = .3)
subplot_arr[1, 0].scatter(df_m_4['Data Value'], df_m_4['pro'],c='b',marker ="^",s=250.,alpha = .6)
subplot_arr[1, 0].scatter(df_m4['Data Value'], df_m4['pro'],c='r',marker = "*",s=400.,alpha = .6)
subplot_arr[1, 0].set_ylabel('创造智能类任务计算机化水平',fontsize = 35)
subplot_arr[1, 0].set_xlabel('社会洞察力',fontsize = 35)
subplot_arr[1, 0].tick_params(labelsize=20)

subplot_arr[1, 1].scatter(df5['Data Value'], df5['pro'],c='#696969',s=100.,alpha = .3)
# subplot_arr[1, 1].set_ylabel('计算机化水平',fontsize = 20)
subplot_arr[1, 1].scatter(df_m_5['Data Value'], df_m_5['pro'],c='b',marker = "^",s=250.,alpha = .6)
subplot_arr[1, 1].scatter(df_m5['Data Value'], df_m5['pro'],c='r',marker = "*",s=400.,alpha = .6)
subplot_arr[1, 1].set_xlabel('艺术',fontsize = 35)
subplot_arr[1, 1].tick_params(labelsize=20)

subplot_arr[1, 2].scatter(df6['Data Value'], df6['pro'],c='#696969',s=100.,alpha = .3)
subplot_arr[1, 2].scatter(df_m_6['Data Value'], df_m_6['pro'],c='b',marker = "^",s=250.,alpha = .6)
subplot_arr[1, 2].scatter(df_m6['Data Value'], df_m6['pro'],c='r',marker = "*",s=400.,alpha = .6)
# subplot_arr[1, 2].set_ylabel('计算机化水平',fontsize = 20)
subplot_arr[1, 2].set_xlabel('原创性',fontsize = 35)
subplot_arr[1, 2].tick_params(labelsize=20)

subplot_arr[2, 0].scatter(df7['Data Value'], df7['pro'],c='#696969',s=100.,alpha = .3)
subplot_arr[2, 0].set_ylabel('感知操作类任务计算机化水平',fontsize = 35)
subplot_arr[2, 0].scatter(df_m_7['Data Value'], df_m_7['pro'],c='b',marker = "^",s=250.,alpha = .6)
subplot_arr[2, 0].scatter(df_m7['Data Value'], df_m7['pro'],c='r',marker = "*",s=400.,alpha = .6)
subplot_arr[2, 0].set_xlabel('手工灵巧度',fontsize = 35)
subplot_arr[2, 0].tick_params(labelsize=20)

subplot_arr[2, 1].scatter(df8['Data Value'], df8['pro'],c='#696969',s=100.,alpha = .3)
# subplot_arr[2, 1].set_ylabel('计算机化水平',fontsize = 20)
subplot_arr[2, 1].set_xlabel('手指灵活度',fontsize = 35)
subplot_arr[2, 1].scatter(df_m_8['Data Value'], df_m_8['pro'],c='b',marker = "^",s=250.,alpha = .6)
subplot_arr[2, 1].scatter(df_m8['Data Value'], df_m8['pro'],c='r',marker = "*",s=400.,alpha = .6)
subplot_arr[2, 1].tick_params(labelsize=20)

subplot_arr[2, 2].scatter(df9['Data Value'], df9['pro'],c='#696969',s=100.,alpha =.3)
# subplot_arr[2, 2].set_ylabel('计算机化水平',fontsize = 20)
subplot_arr[2, 2].scatter(df_m_9['Data Value'], df_m_9['pro'],c='b',marker = "^",s=250.,alpha = .6)
subplot_arr[2, 2].scatter(df_m9['Data Value'], df_m9['pro'],c='r',marker = "*",s=400.,alpha = .6)
subplot_arr[2, 2].set_xlabel('拥挤的工作空间',fontsize = 35)
subplot_arr[2, 2].tick_params(labelsize=20)


subplot_arr[0, 0].text(2.4,0.95,'R=-0.49,p=8.87e-60',fontsize=35)
subplot_arr[0, 1].text(2.0,0.95,'R=-0.76,p=3.65e-182',fontsize=35)
subplot_arr[0, 2].text(1.95,0.95,'R=-0.71,p=1.61e-147',fontsize=35)
subplot_arr[1, 0].text(1.9,0.95,'R=-0.80,p=3.15e-219',fontsize=35)
subplot_arr[1, 1].text(2.2,0.95,'R=-0.27,p=3.81e-18',fontsize=35)
subplot_arr[1, 2].text(1.95,0.95,'R=-0.76,p=1.34e-184',fontsize=35)
subplot_arr[2, 0].text(1.8,0.95,'R=-0.15,p= 3.64e-06',fontsize=35)
subplot_arr[2, 1].text(2.35,0.95,'R=-0.03,p=0.313',fontsize=35)
subplot_arr[2, 2].text(2.4,0.95,'R=-0.01,p=0.753',fontsize=35)



plt.legend(['全行业','媒体行业','内容生产类媒体行业'],bbox_to_anchor=(1,3.8),fontsize=35)

# %%
from scipy.stats import pearsonr
pccs1= pearsonr(df1['Data Value'], df1['pro'])
pccs2= pearsonr(df2['Data Value'], df2['pro'])
pccs3= pearsonr(df3['Data Value'], df3['pro'])
pccs4= pearsonr(df4['Data Value'], df4['pro'])
pccs5= pearsonr(df5['Data Value'], df5['pro'])
pccs6= pearsonr(df6['Data Value'], df6['pro'])
pccs7= pearsonr(df7['Data Value'], df7['pro'])
pccs8= pearsonr(df8['Data Value'], df8['pro'])
pccs9= pearsonr(df9['Data Value'], df9['pro'])

# %%
pccs9
# Out:
# (-0.010128645525739288, 0.753090164906232)
